# %% [markdown]
# <a href="https://colab.research.google.com/github/felipetavaressilvaoliveira-netizen/senacai/blob/main/resolvendo_porta_XOR_Senac_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Entrada: 2 neurônios (as duas entradas da porta lógica).

# Camada Oculta: 2 ou 3 neurônios (com função de ativação Sigmóide).

#Saída: 1 neurônio (o resultado predito).

# %%
import numpy as np
#Função de ativação (sigmoide) e sua derivada
def sigmoid(x):
  return 1 / 1(1 + np.exp(-x))

def sigmoid_derivative(x):
  return x * (1 - x)

#preparando os dados
# Entrada: A, B

inputs = np.array([[0,0], [0,1], [1,0], [1,1]])
#saida esoerada

expected_output = np.array([[0], [1], [1], [0]])

#Iniciando pesos e BIAS (aleatorios)
inputLayerNeurons, hiddenLayerNeurons, outputLayerNeurons = 2, 2, 1

#Pesos entrada e camada oculta
hidden_weight = np.random.uniform(size=(imputLayerNeurons, hiddenLayerNeurons))
#Peso camada oculta e saida
output_weights = np.random.uniform(size=(hiddenLayerNeurons, outputLayerNeurons))

#taxa de aprendizado + épocas
lr = 0.5
epochs = 10000

#backpropagation
for epochs in range(epoch):
  hidden_layer_activation = np.dot(inputs, hidden_weights)
  hidden_layer_output = sigmoid(hidden_layer_activation)

  output_layer_activation = np.dot(hidden_layer_output, output_weights)
  predicted_output = sigmoid(output_layer_activation)

  # Cálculo do erro
  error = expected_output - predicted_output

    # Gradiente na saída
  d_predicted_output = error * sigmoid_derivative(predicted_output)

    # Erro na camada oculta
  error_hidden_layer = d_predicted_output.dot(output_weights.T)
  d_hidden_layer = error_hidden_layer * sigmoid_derivative(hidden_layer_output)

    # Atualização dos pesos
  output_weights += hidden_layer_output.T.dot(d_predicted_output) * lr
  hidden_weights += inputs.T.dot(d_hidden_layer) * lr

# 5 Teste
print("Resultados após o treinamento:")
for i in range(len(inputs)):
    pred = sigmoid(np.dot(sigmoid(np.dot(inputs[i], hidden_weights)), output_weights))
    print(f"Entrada: {inputs[i]} -> Predição: {pred[0]:.4f} (Esperado: {expected_output[i][0]})")
# Out:
# <>:4: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# <>:4: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# /tmp/ipykernel_542/2338036106.py:4: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
#   return 1 / 1(1 + np.exp(-x))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_542/2338036106.py in <cell line: 0>()
#      19
#      20 #Pesos entrada e camada oculta
# ---> 21 hidden_weight = np.random.uniform(size=(imputLayerNeurons, hiddenLayerNeurons))
#      22 #Peso camada oculta e saida
#      23 output_weights = np.random.uniform(size=(hiddenLayerNeurons, outputLayerNeurons))
#
# NameError: name 'imputLayerNeurons' is not defined
